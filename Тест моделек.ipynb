# %% [markdown]
# Устанавливаем библиотеку пандас и имортируем ее (обязательно процент при установке,а не ! тк устанавливает неправильно)

# %%
# %pip install pandas
# Out:
# ...
#   Using cached pandas-2.3.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
# Using cached pandas-2.3.3-cp313-cp313-win_amd64.whl (11.0 MB)
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.3 MB 2.1 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.8/12.3 MB 3.2 MB/s eta 0:00:04
#    --------- ------------------------------ 2.9/12.3 MB 3.7 MB/s eta 0:00:03
#    ------------- -------------------------- 4.2/12.3 MB 4.3 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.2/12.3 MB 4.4 MB/s eta 0:00:02
#    -------------------- ------------------- 6.3/12.3 MB 4.6 MB/s eta 0:00:02
#    ------------------------ --------------- 7.6/12.3 MB 4.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.9/12.3 MB 4.9 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
data = pd.read_csv('train.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 data = pd.read_csv('train.csv')
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
import oc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import oc
#
# ModuleNotFoundError: No module named 'oc'

# %%
import os
print(os.getcwd())
# Out:
# d:\games\Microsoft VS Code
